# %% [markdown]
# ## 常见事件类型
# * QUIT             none
# * KEYDOWN          unicode, key, mod
# * KEYUP            key, mod
# * MOUSEMOTION      pos, rel, buttons
# * MOUSEBUTTONUP    pos, button
# * MOUSEBUTTONDOWN  pos, button
#
# ** 所有的事件都放置到内置队列列表里，取出的方式是先进先出 **
#
# ## 获取所有的事件
# ** pygame.event.get() **
#
# ## 获取特定的事件类型
# ** pygame.event.get(type) **
# 注意：每一次获取单独的事件类型之后，要记得取出其他的事件，免得队列里面有太多的事件堆叠起来。
#
# ## 获取特定按键
# ** keys = pygame.key.pressed() ** 获取所有的按键，里面有true和false来设置是否按下这个按键
# ** `keys[按键的常量]` ** 根据索引获取到的true还是false来得知是否按下了没有

# %%
#要使用必先导入
import pygame
#导入pygame中的所有常量
from pygame.locals import *
import sys


#初始化PyGame
pygame.init()
#创建一个600*500的窗口
screen = pygame.display.set_mode((600,500))

#打印文字到窗口
myfont = pygame.font.Font(None,60)
#RGB,R红色，G绿色，B蓝色
white = (255,255,255)
blue = (0,0,255)
textImage = myfont.render('Hello PyGame',True,white)

while True:
#   第一种，一次性获取所有事件，然后根据判断事件类型，从而处理相对应的事件
    for event in pygame.event.get():
        if event.type == QUIT:
            sys.exit()

    
       
            print('系统即将返回')
    # 清理屏幕，绘制，然后刷新
    screen.fill(blue)
    screen.blit(textImage, (100, 100))
    pygame.display.update()

# %%
# %%writefile event2.py
#要使用必先导入
import pygame
#导入pygame中的所有常量
from pygame.locals import *
import sys


#初始化PyGame
pygame.init()
#创建一个600*500的窗口
screen = pygame.display.set_mode((600,500))

#打印文字到窗口
myfont = pygame.font.Font(None,60)
#RGB,R红色，G绿色，B蓝色
white = (255,255,255)
blue = (0,0,255)
textImage = myfont.render('Hello PyGame',True,white)

while True:
#   第二种，根据你需要获取的事件类型，从而获取事件对象
    #从事件列表里获取某种类型的事件对象
#     quitList = pygame.event.get(QUIT)
#     if len(quitList) > 0:
#         sys.exit()
#         print('系统即将返回')
        
        
    keyList = pygame.event.get(KEYDOWN)
    if len(keyList) > 0:
        print('按键事件')
        
        
    pygame.event.get()
       
        
    # 清理屏幕，绘制，然后刷新
    screen.fill(blue)
    screen.blit(textImage, (100, 100))
    pygame.display.update()
# Out:
# Overwriting event2.py

# %%
# !python event2.py

# %%
# %%writefile event.py
#要使用必先导入
import pygame
#导入pygame中的所有常量
from pygame.locals import *
import sys


#初始化PyGame
pygame.init()
#创建一个600*500的窗口
screen = pygame.display.set_mode((600,500))

#打印文字到窗口
myfont = pygame.font.Font(None,60)
#RGB,R红色，G绿色，B蓝色
white = (255,255,255)
blue = (0,0,255)
textImage = myfont.render('Hello PyGame',True,white)
num = 0
eventList =[]
while True:
    for event in pygame.event.get(): #循环从pygame事件模块里获取的所有的事件
        if event.type in (QUIT, KEYDOWN):#每一个事件都会有type属性
            sys.exit()
        
        
        

        
    # 清理屏幕，绘制，然后刷新
    screen.fill(blue)
    screen.blit(textImage, (100, 100))
    pygame.display.update()
# Out:
# Overwriting event.py

# %%
#QUIT,KEYDOWN,KEYUP,MOUSEBUTTONDOWN,MOUSEBUTTONUP

#实时事件循环
# for event in pygame.event.get(): #循环从pygame事件模块里获取的所有的事件
#     if event.type in (QUIT, KEYDOWN):#每一个事件都会有type属性
#         sys.exit()

# %%
# %%writefile pygameEvent.py
#要使用必先导入
import pygame
#导入pygame中的所有常量
from pygame.locals import *
import sys


#初始化PyGame
pygame.init()
#创建一个600*500的窗口
screen = pygame.display.set_mode((600,500))

#打印文字到窗口
# myfont = pygame.font.Font(None,60)
#RGB,R红色，G绿色，B蓝色
white = (255,255,255)
blue = (0,0,255)
# textImage = myfont.render('Hello PyGame',True,white)
# print(QUIT)
# print(KEYDOWN)

while True:
#   
    a = pygame.event.get(MOUSEBUTTONDOWN)
    if  len(a)>0:
        print(a)
    for event in pygame.event.get():
        if event.type in (QUIT,KEYDOWN):
            pygame.quit()
            sys.exit()
        print(event)
        print(event.type)
        print(event.__dir__())
        
        keys = pygame.key.get_pressed()
        if keys[K_ESCAPE]:
            print('系统即将返回')
        if keys[K_t]:
            print('当前系统按下了T键')
    # 清理屏幕，绘制，然后刷新
    screen.fill(blue)
#     screen.blit(textImage, (100, 100))
    pygame.display.update()
# Out:
# Overwriting pygameEvent.py

# %%
# !python pygameEvent.py
# Out:
# pygame 1.9.4
# Hello from the pygame community. https://www.pygame.org/contribute.html
# <Event(17-VideoExpose {})>
# 17
# ['__repr__', '__getattribute__', '__setattr__', '__delattr__', '__lt__', '__le__', '__eq__', '__ne__', '__gt__', '__ge__', '__bool__', '__dict__', 'type', 'dict', '__doc__', '__hash__', '__str__', '__init__', '__new__', '__reduce_ex__', '__reduce__', '__subclasshook__', '__init_subclass__', '__format__', '__sizeof__', '__dir__', '__class__']
# <Event(16-VideoResize {'size': (600, 500), 'w': 600, 'h': 500})>
# 16
# ['size', 'w', 'h', '__repr__', '__getattribute__', '__setattr__', '__delattr__', '__lt__', '__le__', '__eq__', '__ne__', '__gt__', '__ge__', '__bool__', '__dict__', 'type', 'dict', '__doc__', '__hash__', '__str__', '__init__', '__new__', '__reduce_ex__', '__reduce__', '__subclasshook__', '__init_subclass__', '__format__', '__sizeof__', '__dir__', '__class__']
# <Event(1-ActiveEvent {'gain': 0, 'state': 1})>
# 1
# ...
